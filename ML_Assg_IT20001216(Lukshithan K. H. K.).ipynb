# %%
###############################################
#                                             #
# import libraries and assign aliases to them #
#                                             #
###############################################

import pandas as pd             # provides data structures for efficiently handling large datasets 
                                # and a variety of tools for data manipulation, filtering, and analysis
    
import numpy as np              # provides data structures for efficiently handling large arrays and matrices, 
                                # and a variety of tools for mathematical operations and linear algebra
    
import matplotlib.pyplot as plt # provides a wide range of tools for creating static, animated, 
                                # and interactive visualizations in various formats. pyplot is 
                                # a sub-library of matplotlib that provides a convenient interface 
                                # for creating and customizing plots, charts, and figures
            
import seaborn as sns           # provides a higher-level interface to create a variety of statistical graphics 
                                # such as heatmaps, bar plots, violin plots, scatter plots, and many more. seaborn is 
                                # built on top of matplotlib, which means that it uses matplotlib under the hood and 
                                # extends its functionality with more advanced and specialized plots

# %%
data=pd.read_csv("fetal_health.csv") # reads the CSV file, "fetal_health.csv" and creates a Pandas DataFrame object 
                                     # named "data" from its contents. The read_csv() method from the Pandas library is 
                                     # used to read the CSV file, and the resulting DataFrame object is assigned to the 
                                     # variable data. Once the data is loaded into the DataFrame, it can be manipulated, 
                                     # analyzed, and visualized using the various tools provided by Pandas

# %%
data.head() # data.head() is a method call in Python that returns the first 5 rows of a Pandas DataFrame object named 
            # data. It can be used to quickly examine the structure and content of a dataset, including the column names
            # and values in each cell
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
print(f"Columns in dataset :\n{data.columns}") # This code prints the column names of a Pandas DataFrame object named data in a 
                                               # formatted way using a print statement with a formatted string
# Out:
# Columns in dataset :
# Index(['baseline value', 'accelerations', 'fetal_movement',
#        'uterine_contractions', 'light_decelerations', 'severe_decelerations',
#        'prolongued_decelerations', 'abnormal_short_term_variability',
#        'mean_value_of_short_term_variability',
#        'percentage_of_time_with_abnormal_long_term_variability',
#        'mean_value_of_long_term_variability', 'histogram_width',
#        'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
#        'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
#        'histogram_median', 'histogram_variance', 'histogram_tendency',
#        'fetal_health'],
#       dtype='object')

# %%
data.describe().T # data.describe().T is a method chaining expression in Python that computes summary statistics of each
                  # numerical column in a Pandas DataFrame object named data using the describe() method, and then 
                  # transposes the resulting DataFrame using the .T attribute. The resulting transposed DataFrame displays 
                  # the summary statistics of each column as rows, making it easier to read and understand
# Out:
#                                                      count        mean  \
# baseline value                                      2126.0  133.303857
# accelerations                                       2126.0    0.003178
# fetal_movement                                      2126.0    0.009481
# uterine_contractions                                2126.0    0.004366
# light_decelerations                                 2126.0    0.001889
# severe_decelerations                                2126.0    0.000003
# prolongued_decelerations                            2126.0    0.000159
# abnormal_short_term_variability                     2126.0   46.990122
# mean_value_of_short_term_variability                2126.0    1.332785
# percentage_of_time_with_abnormal_long_term_vari...  2126.0    9.846660
# mean_value_of_long_term_variability                 2126.0    8.187629
# histogram_width                                     2126.0   70.445908
# ...

# %%
data.info(verbose=True) # displays the column names, data types, and number of non-null values for each column. The verbose 
                        # parameter set to True provides a more detailed output, showing the number of non-null values for 
                        # each column. This method is useful for data quality checks and data exploration tasks
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
# identify which columns in the DataFrame data contain missing values, and how many missing values there are in each of 
# those columns

missing_values = data.columns[data.isnull().any()]           # identifies which columns in the Pandas DataFrame
                                                             # data contain missing values by creating an index of 
                                                             # the column names with at least one missing value
        
print(f"Missing values:\n{data[missing_values].isnull().sum()}") #  prints the number of missing values for each column in 
                                                                 # the DataFrame with missing values

# identify which columns in the DataFrame data contain null or NaN values, and how many null values there are in each of 
# those columns

null_values = data.columns[data.isna().any()] # creates an index of the column names in the Pandas DataFrame data 
                                              # that contain null or NaN values
    
print(f"Null values:\n{data[null_values].isna().sum()}") # prints the number of null or NaN values for each column in the 
                                                         # DataFrame that has null values
# Out:
# Missing values:
# Series([], dtype: float64)
# Null values:
# Series([], dtype: float64)

# %%
data["fetal_health"].describe() # summarizes statistical information about the "fetal_health" column in the DataFrame 
                                # data, including the count of non-null values, mean, standard deviation, and minimum 
                                # and maximum values
# Out:
# count    2126.000000
# mean        1.304327
# std         0.614377
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         3.000000
# Name: fetal_health, dtype: float64

# %%
total = data["fetal_health"].sum() # the sum of all values in the "fetal_health" column of the DataFrame data and stores 
                                   # the result in the variable total. This calculation provides information on the total 
                                   # value of the "fetal_health" variable in the dataset, but it assumes that each data 
                                   # point has equal weight, which may not be the case in all scenarios
            
normal = total - 471                   #From the given dataset Normal = (Total - (Suspect + Pathological))
suspect = total - 1831                 #From the given dataset Suspect = (Total - (Normal + Pathological))
pathological = total - 1950            #From the given dataset Pathological = (Total - (Normal + Suspect))

print(data["fetal_health"].value_counts()) #  prints out the count of each unique value in the "fetal_health" column of 
                                           # the DataFrame data, which provides a quick summary of the distribution of 
                                           # the fetal health status variable in the dataset

plt.figure(figsize = (10,5)) #  set the figure size of the plot
plt.subplot(121) # creates a subplot with 1 row and 2 columns and selects the first column for plotting the bar chart

# creates the bar chart
# value_counts() method counts the number of occurrences of each unique value in the "fetal_health" column
# and the resulting counts are plotted using the plot() method
vis_fetal_health = data.fetal_health.value_counts().plot(figsize=(10, 5), kind="bar", color = ["#FF1493", "#FF69B4", "#FFB6C1"])
plt.title("Fetal health count") # title of bar chart
plt.xlabel("Fetal health Status") # label for x axis
plt.ylabel("Number of Cases") # label for y axis

plt.show()
# Out:
# 1.0    1655
# 2.0     295
# 3.0     176
# Name: fetal_health, dtype: int64

# %%
# RF algorithm begins henceforth

# %%
numeric_data = data.select_dtypes(exclude="object") # selects only the columns of the data DataFrame that contain 
                                                    # numeric data
    
numeric_corr = numeric_data.corr()                      # computes the correlation matrix between all pairs of numeric 
                                                        # variables in the numeric_data DataFrame
    
numeric_feature = numeric_corr["fetal_health"].sort_values(ascending=False).head(20).to_frame() # elects the top 20 features 
                                                                                                # (columns) in the numeric_data 
                                                                                                # DataFrame that are most highly
                                                                                                # correlated with the 
                                                                                                # "fetal_health" column
                

cm = sns.light_palette("#5F9EA0", as_cmap=True) #creates a color map object for visualizing the correlation values

style = numeric_feature.style.background_gradient(cmap=cm) # applies the color map to the correlation matrix to create a styled 
                                                           # DataFrame object style
style
# Out:
# <style type="text/css">
# #T_3e483_row0_col0 {
#   background-color: #5f9ea0;
#   color: #f1f1f1;
# }
# #T_3e483_row1_col0 {
#   background-color: #9ac1c2;
#   color: #000000;
# }
# #T_3e483_row2_col0 {
#   background-color: #9cc2c3;
#   color: #000000;
# }
# #T_3e483_row3_col0 {
#   background-color: #a1c5c6;
#   color: #000000;
# }
# #T_3e483_row4_col0 {
#   background-color: #bad4d5;
#   color: #000000;
# }
# #T_3e483_row5_col0 {
#   background-color: #c1d8d9;
#   color: #000000;
# }
# #T_3e483_row6_col0 {
#   background-color: #c3d9da;
#   color: #000000;
# }
# #T_3e483_row7_col0 {
#   background-color: #c8dcdd;
#   color: #000000;
# }
# #T_3e483_row8_col0 {
#   background-color: #cbdedf;
#   color: #000000;
# }
# #T_3e483_row9_col0 {
#   background-color: #ccdedf;
#   color: #000000;
# }
# #T_3e483_row10_col0 {
#   background-color: #d4e4e4;
#   color: #000000;
# }
# #T_3e483_row11_col0 {
#   background-color: #d5e4e4;
#   color: #000000;
# }
# #T_3e483_row12_col0 {
# ...

# %% [markdown]
# Based on the correlation data, it appears that the columns "prolongued_decelerations", "abnormal_short_term_variability", and "percentage_of_time_with_abnormal_long_term_variability" have a strong positive correlation with the "fetal_health" column.

# %% [markdown]
# ## Outlier Identification

# %%
# This code creates a box plot using seaborn to display the distribution of values for each feature in the dataset. It uses 
# boxes to represent the IQR of the data, with whiskers indicating the range of the data, excluding outliers. The color scheme 
# is set by the palette parameter, and the x-axis labels are rotated using xticks. The plot is displayed with show()

plt.figure(figsize=(20,10))
sns.boxplot(data = data, palette = "Set2")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# The BoxPlots above show that the dataset contains many outliers, especially in the features histogram_variance, histogram_mode, histogram_median, and percentage_of_time_with_abnormal_long_term_variability. Consequently, we will start by removing the outliers.

# %% [markdown]
# ## Outlier Removal

# %%
# This code sets the lower and upper limits for the range of acceptable values for the "histogram_variance" feature based on 
# the mean and standard deviation of that feature. It then filters the data to only include values within this range, and 
# returns the number of rows in the filtered dataset. This is a method of removing outliers from the dataset

lowerlimit = data.histogram_variance.mean() - 3*data.histogram_variance.std()
upperlimit = data.histogram_variance.mean() + 3*data.histogram_variance.std()
data = data[(data.histogram_variance > lowerlimit) & (data.histogram_variance < upperlimit)]
data.shape[0]
# Out:
# 2082

# %%
# This code removes outliers in the histogram_median attribute of the dataset. The lower and upper limits are defined using 
# the mean and standard deviation of the attribute, and any data points that fall outside of this range are removed from the 
# dataset. The resulting dataset shape is printed to show how many data points were removed

lowerlimit = data.histogram_median.mean() - 3*data.histogram_median.std()
upperlimit = data.histogram_median.mean() + 3*data.histogram_median.std()
data = data[(data.histogram_median > lowerlimit) & (data.histogram_median < upperlimit)]
data.shape[0]
# Out:
# 2065

# %%
# This code calculates the lower and upper limit of acceptable values for the 
# percentage_of_time_with_abnormal_long_term_variability column in the dataset based on its mean and standard deviation. It 
# then filters out any rows where the percentage_of_time_with_abnormal_long_term_variability value falls outside this 
# acceptable range and updates the dataset with the filtered rows. Finally, it outputs the number of rows remaining in the 
# dataset after the filtering

lowerlimit = data.percentage_of_time_with_abnormal_long_term_variability.mean() - 3*data.percentage_of_time_with_abnormal_long_term_variability.std()
upperlimit = data.percentage_of_time_with_abnormal_long_term_variability.mean() + 3*data.percentage_of_time_with_abnormal_long_term_variability.std()
data = data[(data.percentage_of_time_with_abnormal_long_term_variability > lowerlimit) & (data.percentage_of_time_with_abnormal_long_term_variability < upperlimit)]
data.shape[0]
# Out:
# 2006

# %%
# This code removes the outliers in the 'histogram_max' attribute of the 'data' dataset by defining a lower limit and an upper 
# limit as three standard deviations away from the mean. Then it filters the 'data' dataset to only include the rows where the 
# 'histogram_max' attribute is within the defined range. Finally, it prints the number of rows in the filtered 'data' dataset 
# using the shape[0] attribute.

lowerlimit = data.histogram_max.mean() - 3*data.histogram_max.std()
upperlimit = data.histogram_max.mean() + 3*data.histogram_max.std()
data = data[(data.histogram_max > lowerlimit) & (data.histogram_max < upperlimit)]
data.shape[0]
# Out:
# 1992

# %%
# There are multiple lines of code where outliers are being removed for specific columns in the dataset by specifying a lower 
# and upper limit based on the mean and standard deviation of the column. The resulting dataset shape after removing the 
# outliers is also printed

lowerlimit = data.histogram_mode.mean() - 3*data.histogram_mode.std()
upperlimit = data.histogram_mode.mean() + 3*data.histogram_mode.std()
data = data[(data.histogram_mode > lowerlimit) & (data.histogram_mode < upperlimit)]
data.shape[0]
# Out:
# 1975

# %% [markdown]
# ## Data Scaling and Splitting

# %%
# This code imports the StandardScaler and train_test_split modules from the sklearn.preprocessing and sklearn.model_selection 
# libraries, respectively. These modules are commonly used for data preprocessing and model training in machine learning

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
# the df_columns list is created to store the column names of the dataset. StandardScaler is then applied to the dataset to 
# scale the numerical features by removing the mean and scaling to unit variance. The scaled features are stored in a new 
# DataFrame called X

df_columns = ['baseline value', 'accelerations', 'fetal_movement',
       'uterine_contractions', 'light_decelerations', 'severe_decelerations',
       'prolongued_decelerations', 'abnormal_short_term_variability',
       'mean_value_of_short_term_variability',
       'percentage_of_time_with_abnormal_long_term_variability',
       'mean_value_of_long_term_variability', 'histogram_width',
       'histogram_min', 'histogram_max', 'histogram_number_of_peaks',
       'histogram_number_of_zeroes', 'histogram_mode', 'histogram_mean',
       'histogram_median', 'histogram_variance', 'histogram_tendency']
scale_X = StandardScaler()
X =  pd.DataFrame(scale_X.fit_transform(data.drop(["fetal_health"],axis = 1),), columns = df_columns)
X.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0       -1.385943      -0.847434       -0.196623             -1.523091
# 1       -0.150681       0.689935       -0.196623              0.544809
# 2       -0.047743      -0.078750       -0.196623              1.234109
# 3        0.055196      -0.078750       -0.196623              1.234109
# 4       -0.150681       0.946163       -0.196623              1.234109
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0            -0.626416             -0.031838                 -0.234615
# 1             0.439805             -0.031838                 -0.234615
# 2             0.439805             -0.031838                 -0.234615
# 3             0.439805             -0.031838                 -0.234615
# 4            -0.626416             -0.031838                 -0.234615
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
y = data["fetal_health"] # extracts the column "fetal_health" from the "data" DataFrame and assigns it to the variable "y"

# %%
# This code splits the dataset into training and testing sets using the train_test_split function from the 
# sklearn.model_selection module. The X variable represents the standardized input features, and the y variable represents the 
# target variable, "fetal_health". The function splits the data into 70% training and 30% testing sets, with a random state of '
# 42 for reproducibility. The stratify parameter is used to ensure that the target variable is equally represented in both the 
# training and testing sets. The resulting variables are X_train, X_test, y_train, and y_test, which represent the input and 
# target variables for the training and testing sets, respectively

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42, stratify = y)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((1382, 21), (593, 21), (1382,), (593,))

# %% [markdown]
# ## Random Forest Regression Application

# %%
# imports the RandomForestClassifier class from the sklearn.ensemble module. The RandomForestClassifier is a machine learning 
# model that uses an ensemble of decision trees to make predictions

from sklearn.ensemble import RandomForestClassifier

# %%
# fits a Random Forest Classifier model on the training data (X_train and y_train), and then evaluates the accuracy of the model
# on the test data (X_test and y_test). The accuracy is printed to the console using f-strings. Finally, the model is used to 
# make predictions on the test data, and the predicted values are stored in the variable pred_random_forest

random_forest = RandomForestClassifier()
random_forest_mod = random_forest.fit(X_train, y_train)
print(f"Baseline Random Forest: {round(random_forest_mod.score(X_test, y_test), 3)}")

pred_random_forest = random_forest_mod.predict(X_test)
# Out:
# Baseline Random Forest: 0.939

# %%
# two functions from the sklearn.metrics module that are commonly used to evaluate the performance of a machine learning model

from sklearn.metrics import classification_report, confusion_matrix

# %%
# This code is using the classification_report function from the sklearn.metrics library to print the classification report for 
# the predictions made by the Random Forest model on the test set. The classification report shows several metrics for each 
# class, such as precision, recall, and F1-score, as well as the overall accuracy of the model

print("Classification Report")
print(classification_report(y_test, pred_random_forest))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#          1.0       0.95      0.99      0.97       487
#          2.0       0.87      0.71      0.78        85
#          3.0       1.00      0.67      0.80        21
#
#     accuracy                           0.94       593
#    macro avg       0.94      0.79      0.85       593
# weighted avg       0.94      0.94      0.94       593

# %%
# This code creates a heatmap of the confusion matrix, showing the number of correct and incorrect predictions made by the 
# random forest model on the test set. The x-axis represents the predicted values, while the y-axis represents the actual 
# values. The numbers in each cell indicate the count of observations that fall into that category

ax= plt.subplot()
sns.heatmap(confusion_matrix(y_test, pred_random_forest), annot=True, ax = ax, cmap = "BuPu");

ax.set_xlabel("Predicted labels"); # x-axis label
ax.set_ylabel("True labels");      # y-axis label
ax.set_title("Confusion Matrix");  # title
ax.xaxis.set_ticklabels(["Normal", "Suspect", "Pathological"]); # ticks
